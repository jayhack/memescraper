# %%
# %load_ext autoreload
# %autoreload 2
from imgur import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
data_dirs = os.listdir('./data')
filenames = []
for data_dir in data_dirs:
    filenames += [os.path.join('./data/', data_dir, x) for x in os.listdir(os.path.join('./data/', data_dir))]
filenames = filter(lambda x: x.endswith('.pkl'), filenames)
filenames
# Out:
# ['./data/data_7_1/0-600.pkl',
#  './data/data_7_1/1200-1800.pkl',
#  './data/data_7_1/600-1200.pkl',
#  './data/data_7_2/0-600.pkl',
#  './data/data_7_2/0-600_copy.pkl',
#  './data/data_7_2/1200-1800.pkl',
#  './data/data_7_2/600-1200.pkl',
#  './data/data_7_3/0-600.pkl',
#  './data/data_7_3/1200-1800.pkl',
#  './data/data_7_3/600-1200.pkl']

# %%
import pickle
memes = []
for filename in filenames:
    memes += pickle.load(open(filename, 'r'))

# %%
ids = [m.id for m in memes]
len(set(ids))
# Out:
# 2217

# %%
contents = [m.content for m in memes]

# %%
names = [c.split(':')[0] for c in contents if ':' in c]

# %%
names = filter(lambda x: x.endswith('Meme'), names)

# %%
from collections import Counter
name_counter = Counter(names)

# %%
name_counter.most_common()
# Out:
# [('Unpopular Opinion Puffin Meme', 723),
#  ('Confession Bear Meme', 682),
#  ("Ain't got money for that Meme", 230),
#  ('blah Meme', 228),
#  ('Success Kid Meme', 216),
#  ('Actual Advice Mallard Meme', 165),
#  ('gg Meme', 157),
#  ('Slow Poke Meme', 113),
#  ('First World Problem Meme', 95),
#  ('Philosoraptor Meme', 93),
#  ("Yeah That'd Be Great Meme", 65),
#  ('Bad Luck Brian Meme', 65),
#  ('Am I The Only One Meme', 55),
#  ('Awkward Penguin Meme', 51),
#  ('Grinds My Gears Meme', 49),
#  ('Sudden Clarity Clarence Meme', 48),
#  ('Not Sure Fry Meme', 45),
#  ('Matrix Morpheus Meme', 38),
#  ('Annoyed Picard Meme', 32),
#  ('Almost Politically Correct Redneck Meme', 31),
#  ('Evil Plotting Raccoon Meme', 31),
#  ('Conspiracy Keanu Meme', 28),
#  ('Afraid to Ask Andy Meme', 28),
#  ('Brace Yourself Meme', 28),
#  ('Insanity Wolf Meme', 26),
#  ("You're Gonna Have A Bad Time Meme", 25),
#  ('Tacos and Pickles Meme', 25),
#  ('terrible tiger Meme', 24),
#  ('10 Guy Meme', 24),
#  ('Lazy Spiderman Meme', 23),
#  (',,, Meme', 23),
#  ('The Rent Is Too High Meme', 22),
#  ('Pepperidge Farm Remembers Meme', 20),
#  ('One Does Not Simply Meme', 20),
#  ('I Too Like To Live Dangerously Meme', 19),
#  ('Scumbag Steve Meme', 19),
#  ('Foul Bachelor Frog Meme', 19),
#  ('Confession Kid Meme', 17),
#  ('Joker Mind Loss Meme', 17),
#  ('kfc Meme', 17),
#  ('The Most Interesting Man In The World Meme', 17),
#  ('Fuck Me, Right? Meme', 17),
#  ('Imgur World Problems Meme', 16),
#  ('which is nice Meme', 16),
#  ('Lame Pun Raccoon Meme', 16),
#  ('Foul Bachelorette Frog Meme', 15),
#  ('popular opinion puffin Meme', 15),
#  ('Satisfied Seal Meme', 15),
#  ("But that's none of my business Meme", 14),
#  ('Which is nice guy Meme', 14),
#  ('awkward seal Meme', 13),
#  ('Minor Mistake Marvin Meme', 13),
#  ('Terrible Tiger Meme', 13),
#  ('Child Advice Mallard Meme', 12),
#  ('So hot Meme', 12),
#  ("Aaand It's Gone Meme", 12),
#  ('This hits right at home, and so do I Meme', 12),
#  ('Bad Advice Mallard Meme', 12),
#  ('Condescending Wonka Meme', 11),
#  ('I Should Buy A Boat Meme', 11),
#  ('socially awkward/awesome penguin Meme', 11),
#  ('Depression Dog Meme', 11),
#  ('Scumbag Brain Meme', 11),
#  ('X, X Everywhere Meme', 11),
#  ('too affraid to ask Meme', 11),
#  ('Schrute Facts Meme', 10),
#  ('Saddest cat missed you Meme', 10),
#  ('Socially Awesome Penguin Meme', 10),
#  ('Good Guy Greg Meme', 10),
#  ('Overly Manly Man Meme', 10),
#  ('Grumpy Cat (Tard) Meme', 10),
#  ('Successful Black Man Meme', 10),
#  ('ISIS Shaming Meme', 10),
#  ('imbrewer Meme', 10),
#  ('First world Canadian problems Meme', 10),
#  ('Good Girl Gina Meme', 9),
#  ('child Advice duckling Meme', 9),
#  ('Epiphany kermit Meme', 9),
#  ('Hey there Meme', 9),
#  ('Smug Spongebob Meme', 8),
#  ('Paranoid Parrot Meme', 8),
#  ('Yo Dawg Xzibit Meme', 8),
#  ('bear Meme', 8),
#  ('Woody Woodpecker Meme', 7),
#  ('If I wanted the news I would go to a news site. Meme', 7),
#  ('Lame Joke Eel Meme', 7),
#  ("Like I don't know Meme", 6),
#  ('Therapist Meme', 6),
#  ('Forever Alone Meme', 6),
#  ('Shut Up And Take My Money Meme', 6),
#  ('Stupid Question Girl Meme', 6),
#  ('Idiot Tom Baldwin Meme', 6),
#  ('Joseph Ducreux Meme', 6),
#  ('beer offer Meme', 6),
#  ('Dead Horse is Dead Meme', 6),
#  ('sad rain Meme', 6),
#  ('First Day On The Internet Kid Meme', 5),
#  ('if i had one Meme', 5),
#  ('Business Cat Meme', 5),
#  ('High Expectations Asian Father Meme', 5),
#  ('Drunk Baby Meme', 5),
#  ('College Liberal Meme', 5),
#  ('Popular Opinion Puffin Meme', 5),
#  ('ehe Meme', 5),
#  ('No nose bear Meme', 4),
#  ('real talk nerdy Meme', 4),
#  ('Baby advice mallard Meme', 4),
#  ('cocaine Meme', 4),
#  ('Empathetic Pufferfish Meme', 4),
#  ('Skwisgaar Meme', 4),
#  ('How I got fired from work. Meme', 4),
#  ('Blackmamba Meme', 4),
#  ('Looking at all those cool names nowadays Meme', 4),
#  ('Amazon Cat Meme', 4),
#  (u'L\xe9once Lagarde Meme', 4),
#  ('mario Meme', 4),
#  ('when someone says "Your daughter looks just like you!" Meme', 4),
#  ('Fallout 3 logic Meme', 4),
#  ('uncle sam Meme', 4),
#  ('water Meme', 4),
#  ('Why Not Zoidberg? Meme', 4),
#  ('Scumbag Stacy Meme', 4),
#  ('fear and loathing Meme', 4),
#  ('shrekian Meme', 4),
#  ('Vintage confession bear Meme', 4),
#  ('d&d Meme', 4),
#  ('dank memes Meme', 4),
#  ('satsfied seal Meme', 4),
#  ('gorilla Meme', 4),
#  ('wink Meme', 4),
#  ('Advice Dog Meme', 4),
#  ('.... Meme', 4),
#  ('Scumbag Abbott Meme', 4),
#  ('Afraid To Ask Andy Meme', 4),
#  (u'YEAH Meme', 4),
#  ('Gay Meme', 4),
#  ('Gun Safety Meme', 4),
#  ('GG Jonas Salk Meme', 4),
#  ('Summer Drink Specials Meme', 4),
#  ('ddfg Meme', 4),
#  ('Unimpressed Immortan Joe Meme', 4),
#  ('Non-existent Slowpoke Meme', 4),
#  ('Poster Child Meme', 4),
#  ('Gay Marijuana Meme', 4),
#  ("We should support Pluto's choice Meme", 4),
#  ('andy Meme', 4),
#  ('Priority Peter Meme', 4),
#  ('pc Meme', 4),
#  ('Unpopular Confession Meme', 4),
#  ('Politically correct confession bearneck Meme', 4),
#  (u'Joe Dirt\xe9 Meme', 4),
#  ('locker Meme', 4),
#  ('LASER SPACE ZOMBIE JESUS Meme', 4),
#  ('stay puft Meme', 4),
#  ('3rd World Success Kid Meme', 4),
#  ('Name this meme (ex. Scumbag Steve) Meme', 4),
#  ('MLK MOTHERFUCKING GOAT Meme', 4),
#  ('Reverse Slow Poke Meme', 4),
#  ('Choco Meme', 4),
#  ('hue Meme', 4),
#  ('anti confession morbo Meme', 4),
#  ('4Chan Meme', 4),
#  ('Awkward Moment Sealion Meme', 4),
#  ('Miserable Monty Meme', 4),
#  ('Extremely photogenic labrador Meme', 4),
#  ('al Meme', 4),
#  ('usersub Meme', 4),
#  ('straya cunt Meme', 4),
#  (u'Dead tired college grad Meme', 4),
#  ('sad chad Meme', 4),
#  ('Would you? Meme', 4),
#  ('Did You Know Meme', 4),
#  ('eastern oregonian Meme', 4),
#  ('In light of current events, I thought this was necessary Meme', 4),
#  ('war Meme', 4),
#  ('ISIS shaming Meme', 4),
#  ('peanutbutterjellytime Meme', 4),
#  ('I almost swallowed you Meme', 4),
#  ('Mad Advice Mallard Meme', 4),
#  ('Miller Planet Meme', 4),
#  ('Vive la France Meme', 4),
#  ('Bitches love rolling in the sand Meme', 4),
#  ('a Meme', 4),
#  ('cold pint Meme', 4),
#  ('Name this meme Meme', 4),
#  ('Pedobear Meme', 4),
#  ('Just sitting here Meme', 4),
#  ('MAL REYNOLDS Meme', 4),
#  ('GG Leif Erikson Meme', 4),
#  ('Study Sally slut Meme', 4),
#  ('Winter Meme', 3),
#  ('Bruce Meme', 3),
#  ('jn Meme', 3),
#  ("Things that didn't happen Meme", 3),
#  ('charley is an asshole Meme', 3),
#  ('Katy Meme', 3),
#  ('Bennys Meme', 3),
#  ('Lt Lake Meme', 3),
#  ('Seinfeld phone company Meme', 3),
#  ('Awesome Meme', 3),
#  ('conservs Meme', 3),
#  ('Sour face Meme', 3),
#  ('Forgetful Friar Meme', 3),
#  ('Buzzkill bear Meme', 3),
#  ('Horrifying House Guest Meme', 3),
#  ('For everyone pulling an all-nighter Meme', 3),
#  ('jers Meme', 3),
#  ('Lawyer Meme', 3),
#  ('Gorilla Meme', 3),
#  ('ouch Meme', 3),
#  ('Danny Boy Meme', 3),
#  ('Special hound Meme', 3),
#  ('eyeroll Meme', 3),
#  ('sleep on the floor Meme', 3),
#  ("Don't Like Mondays Meme", 3),
#  (u'sadpens Meme', 3),
#  ('unnecessarily thorough assistant Meme', 3),
#  ('FD secretly hates you Meme', 3),
#  ('Incompetent CNN Meme', 3),
#  ('duckfuk Meme', 3),
#  ('Jurassic World Mom Meme', 3),
#  ('memey Meme', 3),
#  ('Jumping in Meme', 3),
#  ('bad time kocoum Meme', 3),
#  ('paydbets Meme', 3),
#  ('Y U NO Meme', 3),
#  ('Samurai Sword Meme', 3),
#  ('Political Jedi Meme', 3),
#  ('Gory Goose Meme', 3),
#  ('. Meme', 3),
#  ('unpopular opinion puffin Meme', 3),
#  ('jesusbear Meme', 3),
#  ('King Kitty Meme', 3),
#  ('The most interesting gorilla in the world Meme', 3),
#  ('SHRURK Meme', 3),
#  ('Electal Dysfunction Meme', 3),
#  ('baddies Meme', 3),
#  ('Advice God Meme', 3),
#  ('Words of wisdom Meme', 3),
#  ('shrunken head Meme', 3),
#  ('hell id have this ring Meme', 3),
#  ('Dating Site Murderer Meme', 3),
#  ('I have to carry around this sign Meme', 3),
#  ('Warning Jesus Meme', 3),
#  ('Game on Meme', 3),
#  ('puff Meme', 3),
#  ('All your memes! Meme', 3),
#  ('Bedtime Shenanigans Meme', 3),
#  ('A reason to leave Heaven Meme', 3),
#  ('Sales be like, Support be like Meme', 3),
#  ('buzzfeed guy Meme', 3),
#  ('Real ADHD is Meme', 3),
#  ("Rubik's cube for ants? Meme", 3),
#  ('potato Meme', 3),
#  ('FAKE Meme', 3),
#  ("'Murica Meme", 3),
#  ('Awfully Happy Turtle Meme', 3),
#  ('Imgur lately Meme', 3),
#  ('carl Meme', 3),
#  ('Forboding Bronson Meme', 3),
#  ('derploma Meme', 3),
#  ('Cubs Suck Meme', 3),
#  ('white owl problems Meme', 3),
#  ('London right now Meme', 3),
#  ('never again dog Meme', 3),
#  ('two face Meme', 3),
#  ('Just a friendly reminder Meme', 3),
#  ('CHEESE FOR EVERYONE! Meme', 3),
#  ('DieselDan Meme', 3),
#  ('The original disco bear Meme', 3),
#  ('forest fire Meme', 3),
#  ('freddiewin Meme', 3),
#  ('The Road Not Taken Meme', 3),
#  ('FURIOSA Meme', 3),
#  ('Happy Birthday America! Meme', 3),
#  ('Deep Thoughts Meme', 3),
#  ('Capitivity squirrel Meme', 3),
#  ('afgfsg Meme', 3),
#  ('Lazy College Senior Meme', 3),
#  ('insanity pup Meme', 3),
#  ('Cat Meme', 3),
#  ('Gay marriage wins Meme', 3),
#  ('sick Meme', 3),
#  ('mugatu Meme', 3),
#  ('Half-Can Bran Meme', 3),
#  ('zcxvcsd Meme', 3),
#  ('GAHHHH Meme', 3),
#  (', Meme', 3),
#  ('Ye Olde Meme Meme', 3),
#  ('crazy old man Meme', 3),
#  ('deliverance Meme', 3),
#  ('Courage Wolf Meme', 3),
#  ('Worth a shot. Meme', 3),
#  (u'Ancient Aliens Meme', 3),
#  ('4th of July Alcohol Meme', 3),
#  ('Dr Phlox Asks... Meme', 3),
#  ('worm Meme', 3),
#  ('Trooper Meme', 3),
#  ('Unprecedented Meme', 3),
#  ("90's Problems Meme", 3),
#  ('afraid to ask andy Meme', 3),
#  ('Divorce Meme', 3),
#  ('Hawt Link Meme', 3),
#  ('manbun mike Meme', 3),
#  ('Evil Scheme raccoon Meme', 3),
#  ('bro Meme', 3),
#  ('when i see a post worth an upvote Meme', 3),
#  ('Awkward First Date Meme', 3),
#  ('Flash Slowpoke Meme', 3),
#  ('IT LIVES! Meme', 3),
#  ('Surprised Foggy Meme', 3),
#  ('Just my thoughts Meme', 3),
#  ("Life's a beach Meme", 3),
#  ('Judgemental Joe Meme', 3),
#  ('Idiot Nerd Girl Meme', 3),
#  ('Understanding Billy Meme', 3),
#  ('Shit Talking Canadian Meme', 3),
#  ('Scumbag Uterus Meme', 3),
#  ('We are not amused Meme', 3),
#  ('How I feel when browsing /r/Aquariums Meme', 3),
#  ('Sheetz Meme', 3),
#  ('1v1me Meme', 3),
#  ('Naked Jesus Meme', 3),
#  ('handsome gorilla Meme', 3),
#  ('Gay Captain Meme', 3),
#  ('Goodguy Badguy Meme', 3),
#  ('the way Meme', 3),
#  ('Caddyshack Meme', 3),
#  ('Red Head Meme', 3),
#  ('Roplh Meme', 3),
#  ('clinton Meme', 3),
#  ('sarcastic shuttle Meme', 3),
#  ('you da real mvp Meme', 3),
#  ('I am done frog Meme', 3),
#  ('public bathroom Meme', 3),
#  ('You have not lived Meme', 3),
#  ('Cat Lick Meme', 3),
#  ('Colonial Sanders Meme', 3),
#  ('Flamer Meme', 3),
#  ('uncomfortable truths well Meme', 3),
#  ('Hillbillies Meme', 3),
#  ('Indy quim Meme', 3),
#  ('newssss Meme', 3),
#  ('Fallout 2 Wasteland Merc Mod Meme', 3),
#  ('Totes Magoats Meme', 3),
#  ('Still waiting for my Imgur Secret Santa Meme', 3),
#  ('Robbin Hood Meme', 3),
#  ('Deadbeatblacky Meme', 3),
#  ('Unhelpful Highschool Teacher Meme', 3),
#  ('Remedial CNN Meme', 3),
#  ('Actual Advice Duckling Meme', 3),
#  ('Chemistry Cat Meme', 3),
#  ("OMG! John's on fire! Meme", 3),
#  ('Ted Bundy Meme', 3),
#  ('dream job Meme', 3),
#  ('Clueless Christie Meme', 3),
#  ('#1 Mom Casey Meme', 3),
#  ('Kawhi Leonard Meme', 3),
#  ('Chester takes a nap Meme', 3),
#  ('wtf Meme', 3),
#  ('Polygamy Chicken Meme', 3),
#  ('name Meme', 3),
#  ('Bort Meme', 3),
#  ('Torched Meme', 3),
#  ('cat calling Meme', 3),
#  ('Awkward first date Meme', 3),
#  ('Count Rugen Meme', 3),
#  ('Life jacket on a boat Meme', 3),
#  ('Chicago Sold Out Meme', 3),
#  ('In response to the Browns fans Meme', 3),
#  ('I like to think.... Meme', 3),
#  ('How to help a drunk Meme', 3),
#  ('Treehugger problems Meme', 3),
#  ('swomen Meme', 3),
#  ('JonSnowKnowsAll Meme', 3),
#  ('out of shape greece Meme', 3),
#  ('Of Course But Maybe -Louise C.K. Meme', 3),
#  ('doots Meme', 3),
#  ("I'm really really stoned Meme", 3),
#  ('Suspicious kocoum Meme', 3),
#  ('SSD Meme', 3),
#  ('90s kids Meme', 3),
#  ('Scumbag Supreme Court Meme', 3),
#  ('myspace tom Meme', 3),
#  ('X ALL Y Meme', 3),
#  ('General Cock Meme', 3),
#  ('Notorious RBG Meme', 3),
#  ('piggy Meme', 3),
#  ('Equal American Pride Meme', 3),
#  ('Poker Cat Meme', 3),
#  (u"i can't let go Meme", 3),
#  ('xeno Meme', 3),
#  (u'\xaf\\(\xb0_o)/\xaf Meme', 3),
#  ("Don't Goat Time For The Haters Meme", 3),
#  ("Morbo doesn't work that way Meme", 3),
#  ('Frustrated Farnsworth Meme', 3),
#  ('Governor Ratcliffe Meme', 3),
#  ('Awkward Petabyte Meme', 3),
#  ('Bernie Meme', 3),
#  ('greece Meme', 3),
#  ('Ted Meme', 3),
#  ('Wasp Can Meme', 3),
#  ('Scumbag FM Radio Meme', 3),
#  ('imgur Meme', 3),
#  ('Marriage Equality Meme', 3),
#  ("i'm the captain now Meme", 3),
#  ('Advice Duckling Meme', 3),
#  ('I can hear you bear eared fox Meme', 2),
#  ('church Meme', 2),
#  ('BS Lemur Meme', 2),
#  ('Rotten Ralph Meme', 2),
#  ('dalai lama Meme', 2),
#  ('What Year Is It? Meme', 2),
#  ('Rich Slovenia Meme', 2),
#  ('beaver Meme', 2),
#  ('My face when Meme', 2),
#  ('Ye olde meme Meme', 2),
#  ('inapropriate joke tiger Meme', 2),
#  ('Girlfriend in the car Meme', 2),
#  ('dog Meme', 2),
#  ('XD Meme', 2),
#  ('cramps Meme', 2),
#  ('Bewbs Meme', 2),
#  ('The power of fries Meme', 2),
#  ('bag in black Meme', 2),
#  ('First World Cat Problems Meme', 2),
#  ('Proc Doc Meme', 2),
#  ('Scrumbag Radio Meme', 2),
#  ('Conky Meme', 2),
#  ("mother's dildo via amazon Meme", 2),
#  ('Kettering 22872 Subway Meme', 2),
#  ('Immortan Gaben Meme', 2),
#  ('Love God and love each other Meme', 2),
#  ('u wot sloth Meme', 2),
#  ('Dad jokes Meme', 2),
#  ('tell us about the old days grandpa nerd Meme', 2),
#  ('dublin Meme', 2),
#  ('waddams Meme', 2),
#  ('2nd Place Ribbon Meme', 2),
#  ('omg Meme', 2),
#  ('Thug Spider Meme', 2),
#  ('AWESOME FACE Meme', 2),
#  ('Fallout Fuckups Meme', 2),
#  ('andorra Meme', 2),
#  ('Storm Meme', 2),
#  ('daquan Meme', 2),
#  ('Awhhh, Meme', 2),
#  ('Sad Clown Meme', 2),
#  ('Smash Stuff Meme', 2),
#  ('Horace Goes Skiing Meme', 2),
#  ('the void Meme', 2),
#  ('Wise Guy Goat Meme', 2),
#  ('Danke MEEM Meme', 2),
#  ('unethical Meme', 2),
#  ('jail Meme', 2),
#  ('Boris-cat Meme', 2),
#  ('At work today I was asked by someone when my birthday was and, without even thinking, just made up a random date! Meme',
#   2),
#  ('Piggyback Trucks Meme', 2),
#  ('Not what i was expecting first thing in the morning... Meme', 2),
#  ('Skinner Meme', 2),
#  ('Fair Meme', 2),
#  ('office tales Meme', 1),
#  ('Effing Up Meme', 1),
#  ('Boob selfie Meme', 1),
#  ('Fish Meme', 1),
#  ('Riot time Meme', 1),
#  ('marriage Meme', 1),
#  ('Heartbroken Holden Meme', 1),
#  ('Hide Yo Donald Meme', 1),
#  ('jt Meme', 1),
#  ('god thoughts Meme', 1),
#  ('k Meme', 1),
#  ('For that Village I looted... Meme', 1),
#  ('So happy Craig Meme', 1),
#  ('girl hates black coocoo Meme', 1),
#  ('Philosophical puffin Meme', 1),
#  ('Confused Gandalf Meme', 1),
#  ('President Meme', 1),
#  ('Satisfied Coke drinking seal Meme', 1),
#  ('Regretfull Cat Meme', 1),
#  ('Fps Meme', 1),
#  ('The Pinal Answer Meme', 1),
#  ('Putin things in perspective Meme', 1),
#  ('c Meme', 1),
#  ('marriage, protest Meme', 1),
#  ('Afraid to ask Andy Meme', 1),
#  ('cheesebpizza Meme', 1),
#  ('Who owns this car? Meme', 1),
#  ('what a time to be alive Meme', 1),
#  ('Hot cat Meme', 1),
#  ('stalker Meme', 1),
#  ('Let me tell you Meme', 1),
#  ('blue falcon Meme', 1),
#  ('Texas Problems Meme', 1),
#  ('Inception Bear Meme', 1),
#  ('Scumbag Christopher Meme', 1),
#  ('Afterlife Hacks Meme', 1),
#  ('Troll Meme', 1),
#  ('Pop what magnitude Meme', 1),
#  ('red panda Meme', 1),
#  ("Longshankin' SCOTUS Meme", 1),
#  ('Awkward Inception Seal Meme', 1),
#  ('baka batman Meme', 1),
#  ('supergirl says Meme', 1),
#  ('wut Meme', 1),
#  ('Gangster Chappie Meme', 1),
#  ('Phark Week Meme', 1),
#  ('That sinking feeling Meme', 1),
#  ('Cfi Meme', 1),
#  ('upvote post Meme', 1),
#  ('Scumbag Pao Meme', 1),
#  ('turkey pride parade rainbow Meme', 1),
#  ('Every time someone brings up the Lord, God or Jesus Meme', 1),
#  ('Mad Karma Meme', 1),
#  ('Ancient Aliens Daniel Meme', 1),
#  ('bambi Meme', 1),
#  ('Say Anything... On Her Wall Meme', 1),
#  ('Have no fear! Meme', 1),
#  ('SoonFlanker Meme', 1),
#  ('Frustrated Programmer Meme', 1),
#  ('close call Meme', 1),
#  ('Kevin Durant MVP Meme', 1),
#  ('cssify Meme', 1),
#  ('Contradictory Confederate Meme', 1),
#  ('deflector Meme', 1),
#  ('Reddit Detective Meme', 1),
#  ('WONKA ISIS Meme', 1),
#  ('recipe for imgur Meme', 1),
#  ('angry christian Meme', 1),
#  ('Uncomfortable Situation Seal Meme', 1),
#  ('Kamikaze-ISIS parallels Meme', 1),
#  ('Carlton Meme', 1),
#  ('Having fun with silly features Meme', 1),
#  ('Smiling Sunnah Meme', 1),
#  ('voat.co Meme', 1),
#  ("Y'all got anymore Meme", 1),
#  ('Anti-Facts Meme', 1),
#  ('not a good time to remember Meme', 1),
#  ('overly attached fan Meme', 1),
#  ('DigiGG Meme', 1),
#  ('Reddit is dying and all I can think of is this. Meme', 1),
#  ('gh Meme', 1)]
